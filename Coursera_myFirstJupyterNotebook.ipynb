# %% [markdown]
# # My Jupeter Notebook on IBM Watson Studio

# %% [markdown]
# ### Nar Uk

# %% [markdown]
# 100% Human, student to the field of Data Science.

# %% [markdown]
# *This Jupyter Notebook is an inherent from Coursera Peer Review Assignment sample by,* **Romeo Kienzier**.

# %% [markdown]
# ## The following code tests the Gauss formula

# %%
def gauss(n):
    return (n*(n+1))/2

gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# - one
# - two
# - three
# - one
# - two
# - three

# %% [markdown]
# |Markdown|Less|Pretty|
# |-:|-:|-:|
# |Still|renders|**nicely**|
# |1|2|3

# %% [markdown]
# [www.ibm.com](www.ibm.com)
